# %% [markdown]
# **Ohm's Law**:Ohm’s law states that the voltage across a conductor is directly proportional to the current flowing through it, provided all physical conditions and temperatures remain constant.
#
# Mathematically,
#
# V (Voltage) = I (Current) * Resistance (R)
#
# i.e. I = V/R

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# reg.predict(np.array([22.06]).reshape((-1,1)))

# %%
from sklearn import linear_model

import matplotlib.pyplot as plt
import numpy as np

# %%
reg = linear_model.LinearRegression()

# %%
x_train = np.array([0.99,2.03,3.02,26,5.03,6.02,7.05,8,12]).reshape((-1,1))
y_train = np.array([0.4,0.8,1.2,1.9,2.2,1.8,2.9,3.9,4.2])
x_test = np.array([7.5,9,10.5]).reshape((-1,1))
y_test = np.array([3,4,5.01])

# %%
plt.plot(x_train,y_train,'D:g')
plt.show()

# %%
reg.fit(x_train,y_train)

reg.predict(np.array([8]).reshape((-1,1)))
# Out:
# array([3.38169783])

# %%
reg.fit(x_train,y_train)
y_predict = reg.predict(x_test)
print ("Test Values ")
print (y_test)
print ("\n")
print ("Predicted Values ")
print (y_predict)
print ("\n")
# Out:
# Test Values
# [3.   4.   5.01]
#
#
# Predicted Values
# [2.12633159 2.21895415 2.31157671]

# %%
plt.plot(x_test,y_test,'o:r')
plt.show()

plt.plot(x_test,y_predict,'D:b')
plt.show()

# %% [markdown]
# Now we will retrain the model on a differnt dataset: We all know that Force (F) = mass(m) * accleration (a)
#
# => a = F/m
#
# Here is what a formula based calculation looks like
#
# ![image.png](data:image/png;base64,...)

# %%
x_train = np.array([1,5,15,20,50]).reshape([-1,1])
y_train = np.array([0.02,0.1,0.3,0.4,1])
x_test = np.array([23,26,40]).reshape([-1,1])
y_test = np.array([0.46,0.52,0.8])

# %%
plt.plot(x_train,y_train,'D:r')
plt.show()

# %%
reg.fit(x_train,y_train)
y_predict = reg.predict(x_test)
print ("Test Values ")
print (y_test)
print ("\n")
print ("Predicted Values ")
print (y_predict)
print ("\n")
# Out:
# Test Values
# [0.46 0.52 0.8 ]
#
#
# Predicted Values
# [0.46 0.52 0.8 ]

# %%
x_predict = np.array([99,35,45]).reshape([-1,1])
print(reg.predict(x_predict))
# Out:
# [1.98 0.7  0.9 ]
